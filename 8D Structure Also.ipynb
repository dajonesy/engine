# %%
# 8D Structure Also
<!-- 2026.03.27: DAJones created to use a new Sign Table strategy.
-->

# %%
import SignTable as ST
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import SignTable as ST
#
# ModuleNotFoundError: No module named 'SignTable'
